# %%
import pandas as pd

# %%
import os

# %%
os.listdir('./cat_in_dat/')
# Out:
# ['y_test_cat_kaggle.csv', 'train_cat_kaggle.csv', 'test_cat_kaggle.csv']

# %%
train = pd.read_csv('./cat_in_dat/train_cat_kaggle.csv')
test = pd.read_csv('./cat_in_dat/test_cat_kaggle.csv')
y_test = pd.read_csv('./cat_in_dat/y_test_cat_kaggle.csv', header=None)

# %%
print(train.shape, test.shape, y_test.shape)
# Out:
# (479549, 25) (120451, 24) (120451, 1)

# %%
test.head()
# Out:
#    id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0     nom_1    nom_2       nom_3  \
# 0   2    0.0    1.0    0.0     F     N   Red       NaN  Hamster      Canada
# 1   3    NaN    0.0    0.0     F     N   Red    Circle  Hamster     Finland
# 2   8    0.0    0.0    0.0     F     N  Blue   Polygon  Hamster      Russia
# 3  10    0.0    0.0    1.0     T     Y  Blue  Triangle  Hamster     Finland
# 4  16    0.0    0.0    0.0     F     Y   Red  Triangle     Lion  Costa Rica
#
#    ...      nom_8      nom_9 ord_0   ord_1        ord_2 ord_3  ord_4 ord_5  \
# 0  ...  745b909d1        NaN   3.0     NaN     Freezing     n      P    eN
# 1  ...  bdaa56dd1  f9d456e57   1.0  Novice     Lava Hot     a      C   NaN
# 2  ...  94c5fd40c        NaN   1.0  Novice  Boiling Hot     c      N    mX
# 3  ...  28869f8aa  9bfe3ee22   1.0  Novice          Hot     b      O    hG
# 4  ...  d48e8b7af  99f6dca00   1.0  Novice  Boiling Hot     h      E   NaN
#
#    day month
# 0  5.0   9.0
# 1  3.0   3.0
# 2  6.0   3.0
# 3  7.0   5.0
# 4  6.0   7.0
#
# [5 rows x 24 columns]

# %%
train.target.value_counts() * 100 / train.shape[0]
# Out:
# 0    81.245712
# 1    18.754288
# Name: target, dtype: float64

# %%
(train.shape[0] / train.target.value_counts()).values
# Out:
# array([1.23083419, 5.33211395])

# %%
train.head(100)
# Out:
#      id  bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2  \
# 0     0    0.0    0.0    0.0     F     N    Red  Trapezoid  Hamster
# 1     1    1.0    1.0    0.0     F     Y    Red       Star  Axolotl
# 2     4    0.0    NaN    0.0     T     N    Red   Triangle  Hamster
# 3     5    0.0    NaN    1.0     T     N    Red   Triangle     Lion
# 4     6    0.0    0.0    0.0     F     N    Red   Triangle  Hamster
# ..  ...    ...    ...    ...   ...   ...    ...        ...      ...
# 95  120    0.0    0.0    1.0   NaN     N    Red   Triangle      Dog
# 96  122    0.0    0.0    0.0     T     Y    Red   Triangle  Hamster
# 97  123    0.0    0.0    1.0     F     N  Green   Triangle      NaN
# 98  124    0.0    0.0    1.0     F     Y   Blue   Triangle  Hamster
# 99  125    0.0    0.0    0.0     F     N    Red    Polygon  Axolotl
#
#          nom_3  ...      nom_9 ord_0        ord_1     ord_2 ord_3 ord_4  \
# 0       Russia  ...  02e7c8990   3.0  Contributor       Hot     c     U
# 1          NaN  ...  f37df64af   3.0  Grandmaster      Warm     e     X
# 2   Costa Rica  ...  c5361037c   3.0  Grandmaster      Cold     h     C
# 3        China  ...  05afc0f8b   2.0       Expert       Hot     b     Q
# 4   Costa Rica  ...  4d3766412   1.0  Grandmaster      Cold     c     R
# ..         ...  ...        ...   ...          ...       ...   ...   ...
# 95      Russia  ...  6175696eb   3.0       Master      Warm     k     F
# 96  Costa Rica  ...  ebeb7b03d   3.0       Novice  Freezing     c     D
# 97       India  ...  72c4e088e   1.0  Contributor      Warm     e     K
# 98      Canada  ...  31e700296   2.0       Expert  Freezing     d     O
# 99  Costa Rica  ...  d51151a38   1.0       Novice      Warm     b     Y
#
#     ord_5  day month target
# 0      Pw  6.0   3.0      0
# 1      pE  7.0   7.0      0
# 2      OZ  5.0  12.0      0
# 3      wa  3.0   4.0      0
# 4      rg  5.0   6.0      0
# ..    ...  ...   ...    ...
# 95     iv  2.0  12.0      1
# 96     Rj  6.0   7.0      0
# 97     LY  2.0   3.0      0
# 98     Rj  7.0   7.0      0
# 99     Iq  3.0  11.0      0
#
# [100 rows x 25 columns]

# %%
dataset.shape
# Out:
# (600000, 27)

# %%
train.isnull().sum()
# Out:
# id            0
# bin_0     14267
# bin_1     14387
# bin_2     14292
# bin_3     14344
# bin_4     14464
# nom_0     14560
# nom_1     14439
# nom_2     14438
# nom_3     14503
# nom_4     14422
# nom_5     14279
# nom_6     14494
# nom_7     14476
# nom_8     14195
# nom_9     14401
# ord_0     14644
# ord_1     14443
# ord_2     14513
# ord_3     14380
# ord_4     14315
# ord_5     14142
# day       14347
# month     14314
# target        0
# dtype: int64

# %%
print([train[col].nunique() for col in train.columns])
# Out:
# [479549, 2, 2, 2, 2, 2, 3, 6, 6, 6, 4, 1220, 1518, 222, 222, 2218, 3, 5, 6, 15, 26, 190, 7, 12, 2]

# %%
set(train.id) & set(test.id)
# Out:
# set()

# %% [markdown]
# # Drop ids

# %%
train.drop(columns='id', inplace=True)
test.drop(columns='id', inplace=True)

# %%
from sklearn.model_selection import StratifiedKFold

# %%
X, y = train.drop(columns='target'), train['target']

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, shuffle=True)
skf.get_n_splits(X, y)
# Out:
# 5

# %%
X['Set'] = 0.

# %%
i=1
for train_idx, test_idx in skf.split(X, y):
    X.loc[test_idx, 'Set'] = 'train_' + str(i)
    i+=1

# %%
test['Set'] = 'test'

# %%
train_ = pd.concat([X, y], axis=1)

# %%
train_.shape
# Out:
# (479549, 26)

# %%
test['target'] = y_test

# %%
test.shape
# Out:
# (120451, 26)

# %%
y_test.shape
# Out:
# (120451, 1)

# %%
dataset = pd.concat([train_, test], axis=0)

# %%
dataset.shape
# Out:
# (600000, 26)

# %%
dataset.to_csv('./cat_dataset.csv', index=False)

# %%
dataset.target.isnull().sum()
# Out:
# 1

# %%
dataset.shape
# Out:
# (600000, 26)

# %%
# Classifying variables into binary, high and low cardinality nominal, ordinal and dates
binary_vars = [c for c in X.columns if 'bin_' in c]

nominal_vars = [c for c in X.columns if 'nom_' in c]
high_cardinality = [c for c in nominal_vars if len(X[c].unique()) > 16]
low_cardinality = [c for c in nominal_vars if len(X[c].unique()) <= 16]

ordinal_vars = [c for c in X.columns if 'ord_' in c]

time_vars = ['day', 'month']

# %%
X['ord_5_1'] = X['ord_5'].apply(lambda x: x[0] if type(x) == str else np.nan)
X['ord_5_2'] = X['ord_5'].apply(lambda x: x[1] if type(x) == str else np.nan)
Xt['ord_5_1'] = Xt['ord_5'].apply(lambda x: x[0] if type(x) == str else np.nan)
Xt['ord_5_2'] = Xt['ord_5'].apply(lambda x: x[1] if type(x) == str else np.nan)

ordinal_vars += ['ord_5_1', 'ord_5_2']
